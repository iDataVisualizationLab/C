# %% [markdown]
# <table><tr><td>Run the latest release of this notebook:</td><td><a href="https://mybinder.org/v2/gh/stellargraph/stellargraph/master?urlpath=lab/tree/demos/link-prediction/node2vec-link-prediction.ipynb" alt="Open In Binder" target="_parent"><img src="https://mybinder.org/badge_logo.svg"/></a></td><td><a href="https://colab.research.google.com/github/stellargraph/stellargraph/blob/master/demos/link-prediction/node2vec-link-prediction.ipynb" alt="Open In Colab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg"/></a></td></tr></table>

# %% [markdown]
# This demo notebook demonstrates how to predict citation links/edges between papers using Node2Vec on the Cora dataset.
#
# We're going to tackle link prediction as a supervised learning problem on top of node representations/embeddings. The embeddings are computed with the unsupervised node2vec algorithm. After obtaining embeddings, a binary classifier can be used to predict a link, or not, between any two nodes in the graph. Various hyperparameters could be relevant in obtaining the best link classifier - this demo demonstrates incorporating model selection into the pipeline for choosing the best binary operator to apply on a pair of node embeddings.
#
# There are four steps:
#
# 1. Obtain embeddings for each node
# 2. For each set of hyperparameters, train a classifier
# 3. Select the classifier that performs the best
# 4. Evaluate the selected classifier on unseen data to validate its ability to generalise
#
# <a name="refs"></a>
# **References:**
#
# [1] Node2Vec: Scalable Feature Learning for Networks. A. Grover, J. Leskovec. ACM SIGKDD International Conference on Knowledge Discovery and Data Mining (KDD), 2016.

# %%
import matplotlib.pyplot as plt
from math import isclose
from sklearn.decomposition import PCA
import os
import stellargraph as sg

import networkx as nx
import numpy as np
import pandas as pd
from stellargraph import StellarGraph, datasets
from stellargraph.data import EdgeSplitter
from collections import Counter
import multiprocessing
from IPython.display import display, HTML
from sklearn.model_selection import train_test_split

from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN
from tensorflow import keras
from tensorflow.keras import layers, optimizers, losses, metrics, Model, regularizers
from sklearn import preprocessing, feature_extraction, model_selection
from copy import deepcopy
import matplotlib.pyplot as plt
from stellargraph import datasets
from IPython.display import display, HTML
import dill
from sklearn.preprocessing import LabelEncoder
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
import math
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
from copy import deepcopy
import torch
from scipy.sparse import identity
import numpy as np
import logging

import plotly.graph_objects as go
import numpy as np
import pandas as pd 
import os
from sklearn.metrics import precision_recall_curve
from collections import Counter
# from tqdm import tqdm_notebook as tqdm
# tqdm().pandas()
import json
import pickle
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model
from sklearn.model_selection import StratifiedKFold
from keras.models import load_model
from sklearn.metrics import log_loss
from keras import regularizers
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Dropout
from keras.layers import Flatten
import tensorflow as tf
import random
from matplotlib import pyplot as plt
import seaborn as sns
import os
import umap
from sklearn.cluster import KMeans
from keras import backend as K
from sklearn.manifold import TSNE
from IPython.core.display import display, HTML
from sklearn.preprocessing import StandardScaler, MinMaxScaler
display(HTML("<style>.container { width:80% !important; }</style>"))
from plotly.offline import init_notebook_mode, iplot
from sklearn.decomposition import PCA
from stellargraph.data import EdgeSplitter
from stellargraph.mapper import FullBatchLinkGenerator
from stellargraph.layer import GCN, LinkEmbedding


from tensorflow import keras
from sklearn import preprocessing, feature_extraction, model_selection

from stellargraph import globalvar
from stellargraph import datasets
from IPython.display import display, HTML
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/chaupham/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# Using TensorFlow backend.
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## Load the dataset
#
# The Cora dataset is a homogeneous network where all nodes are papers and edges between nodes are citation links, e.g. paper A cites paper B.

# %% [markdown]
# (See [the "Loading from Pandas" demo](../basics/loading-pandas.ipynb) for details on how data can be loaded.)

# %%
path = "../my_data/"

# %%
features_df = pd.read_csv(path + "cancer_mice_data.csv")
features_df.head()
# Out:
#      chr       start         end strand symbol  length  P53KO-O1  p53KO-O2  \
# 0   chr8  68141938.0  68995536.0      +  41699  4832.0     585.0    1034.0
# 1  chr17  33822636.0  33855622.0      -  41700  3972.0    2631.0    3108.0
# 2  chr18  56921369.0  57085202.0      -  41701  1759.0       6.0      26.0
# 3   chr1  72473685.0  72583138.0      -  41702  4191.0       0.0       0.0
# 4  chr19  37282034.0  37298947.0      +  41703  5292.0    4778.0    4921.0
#
#    p53KO-O-CAS1  p53KO-O-CAS2  ...           FDR  RAS/WT-O-L2FC      PValue.1  \
# 0         806.0         746.0  ...  7.613703e-01           3.36  7.350000e-18
# 1        2833.0        2821.0  ...  3.463080e-04          -0.21  6.013309e-01
# 2          34.0          24.0  ...  7.737728e-01          -0.86  5.345735e-02
# 3           6.0           2.0  ...  6.157249e-02           0.00  1.000000e+00
# 4        4569.0        4307.0  ...  2.576700e-07           0.47  1.703489e-02
#
#           FDR.1  53KO/WT-Lg2FCh      PValue.2         FDR.2  CASvWT-Lg2FCh  \
# 0  9.290000e-16        3.551469  4.090000e-26  3.240000e-24       3.134750
# 1  1.000000e+00       -0.219320  2.086368e-01  4.064648e-01      -0.993011
# 2  2.123310e-01       -2.349920  2.684855e-03  9.652530e-03      -0.766251
# 3  1.000000e+00        0.000000  1.000000e+00  1.000000e+00       1.979800
# 4  8.977116e-02        0.322160  5.467157e-01  8.592461e-01      -0.622518
#
#        PValue.3         FDR.3
# 0  6.110000e-20  6.460000e-19
# 1  9.940000e-06  3.370000e-05
# 2  1.051426e-02  2.334048e-02
# 3  6.369788e-02  1.209788e-01
# 4  1.740115e-03  4.395205e-03
#
# [5 rows x 50 columns]

# %%
avg_cols = ['P53KO-O1',
       'p53KO-O2', 'p53KO-O-CAS1', 'p53KO-O-CAS2', 'p53KO-O-RAS1',
       'p53KO-O-RAS2', 'WT-O1', 'WT-O2']




features_df = features_df[avg_cols + ['symbol']]

# %%
feature_cols = avg_cols
len(feature_cols)
# Out:
# 8

# %%
features_df.symbol
# Out:
# 0         41699
# 1         41700
# 2         41701
# 3         41702
# 4         41703
#           ...
# 19310    Zyg11b
# 19311       Zyx
# 19312     Zzef1
# 19313      Zzz3
# 19314       NaN
# Name: symbol, Length: 19315, dtype: object

# %%
df=pd.read_csv(path + "PathwayCommons.sif", sep="\t", header=None)
df.columns = ["gene1", "connection", "gene2"]

df  = df[["gene1", "gene2", "connection"]]
df.columns = ["source", "target", "weight"]
df["weight"] = 1
df.head()
# Out:
#    source    target  weight
# 0   GNGT2     GNGT1       1
# 1    CFL1  SERPINH1       1
# 2    CFL2      CFL1       1
# 3  OR10J5     GNGT1       1
# 4   LUZP4      CFL2       1

# %%
df.source = df.source.apply(lambda x: str(x).lower())
df.target = df.target.apply(lambda x: str(x).lower())

# %%
features_df = features_df.drop_duplicates(subset= ["symbol"]).dropna(subset=["symbol"])

features_df.symbol = features_df.symbol.apply(lambda x: str(x).lower())
features_df.symbol
# Out:
# 0         41699
# 1         41700
# 2         41701
# 3         41702
# 4         41703
#           ...
# 19309    zyg11a
# 19310    zyg11b
# 19311       zyx
# 19312     zzef1
# 19313      zzz3
# Name: symbol, Length: 19312, dtype: object

# %%
print(len(set(features_df.symbol)))
print(len(set.intersection(set(features_df.symbol), set(df.source))))
print(len(set.intersection(set(features_df.symbol), set(df.target))))


overlapping_genes = set.intersection(set(features_df.symbol), set.union(set(df.target),  set(df.source) )) 
print(len(overlapping_genes))
# Out:
# 19312
# 13389
# 13892
# 14318

# %%
all_genes = set.union(set(df.target), set(df.source))
print(len(overlapping_genes))
gene_df = pd.DataFrame({"gene":list(overlapping_genes)})
gene_df = pd.merge(gene_df, features_df, left_on="gene", right_on="symbol", how="left")
print(gene_df.shape)
gene_df = gene_df.drop(columns=["symbol"])
gene_df = gene_df.fillna(0)
# Out:
# 14318
# (14318, 10)

# %%
gene_df.dtypes
# Out:
# gene             object
# P53KO-O1        float64
# p53KO-O2        float64
# p53KO-O-CAS1    float64
# p53KO-O-CAS2    float64
# p53KO-O-RAS1    float64
# p53KO-O-RAS2    float64
# WT-O1           float64
# WT-O2           float64
# dtype: object

# %%
df= df[df.source.isin(overlapping_genes)]
df = df[df.target.isin(overlapping_genes)]

# %%
graph = StellarGraph( nodes={"gene": gene_df.set_index("gene") }, edges={"interact": df})
print("Done!")
print(graph.info())
# Out:
# Done!
# StellarGraph: Undirected multigraph
#  Nodes: 14318, Edges: 657433
#
#  Node types:
#   gene: [14318]
#     Features: float32 vector, length 8
#     Edge types: gene-interact->gene
#
#  Edge types:
#     gene-interact->gene: [657433]
#         Weights: all 1 (default)
#         Features: none

# %%
#### Write
import dill
with open('/Users/chaupham/Downloads/gene_and_nodefeatures.pkl', 'wb') as f:     
    dill.dump(graph, f)

# %% [markdown]
# ## Construct splits of the input data
#
# We have to carefully split the data to avoid data leakage and evaluate the algorithms correctly:
#
# * For computing node embeddings, a **Train Graph** (`graph_train`)
# * For training classifiers, a classifier **Training Set** (`examples_train`) of positive and negative edges that weren't used for computing node embeddings
# * For choosing the best classifier, an **Model Selection Test Set** (`examples_model_selection`) of positive and negative edges that weren't used for computing node embeddings or training the classifier
# * For the final evaluation, a **Test Graph** (`graph_test`) to compute test node embeddings with more edges than the Train Graph, and a **Test Set** (`examples_test`) of positive and negative edges not used for neither computing the test node embeddings or for classifier training or model selection

# %% [markdown]
# ###  Test Graph
#
# We begin with the full graph and use the `EdgeSplitter` class to produce:
#
# * Test Graph
# * Test set of positive/negative link examples
#
# The Test Graph is the reduced graph we obtain from removing the test set of links from the full graph.

# %%
G=graph

# %%
edge_splitter_test = EdgeSplitter(G)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from G, and obtain the
# reduced graph G_test with the sampled links removed:
G_test, edge_ids_test, edge_labels_test = edge_splitter_test.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 65743 positive and 65743 negative edges. **

# %% [markdown]
# ### Train Graph
#
# This time, we use the `EdgeSplitter` on the Test Graph, and perform a train/test split on the examples to produce:
#
# * Train Graph
# * Training set of link examples
# * Set of link examples for model selection

# %%
edge_splitter_train = EdgeSplitter(G_test)

# Randomly sample a fraction p=0.1 of all positive links, and same number of negative links, from G_test, and obtain the
# reduced graph G_train with the sampled links removed:
G_train, edge_ids_train, edge_labels_train = edge_splitter_train.train_test_split(
    p=0.1, method="global", keep_connected=True
)
# Out:
# ** Sampled 59169 positive and 59169 negative edges. **

# %%
print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 14318, Edges: 657433
#
#  Node types:
#   gene: [14318]
#     Features: float32 vector, length 8
#     Edge types: gene-interact->gene
#
#  Edge types:
#     gene-interact->gene: [657433]
#         Weights: all 1 (default)
#         Features: none

# %%
print(G_test.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 14318, Edges: 591690
#
#  Node types:
#   gene: [14318]
#     Features: float32 vector, length 8
#     Edge types: gene-interact->gene
#
#  Edge types:
#     gene-interact->gene: [591690]
#         Weights: all 1 (default)
#         Features: none

# %%
print(G_train.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 14318, Edges: 532521
#
#  Node types:
#   gene: [14318]
#     Features: float32 vector, length 8
#     Edge types: gene-interact->gene
#
#  Edge types:
#     gene-interact->gene: [532521]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# Below is a summary of the different splits that have been created in this section

# %%
epochs = 300
train_gen = FullBatchLinkGenerator(G_train, method="gcn")
train_flow = train_gen.flow(edge_ids_train, edge_labels_train)
test_gen = FullBatchLinkGenerator(G_test, method="gcn")
test_flow = test_gen.flow(edge_ids_test, edge_labels_test)

gcn = GCN(
    layer_sizes = [20, 10, 5], activations=["elu", "elu", "softmax"], generator=train_gen, dropout=0.1)
x_inp, x_out = gcn.in_out_tensors()

prediction = LinkEmbedding(activation="relu", method="ip")(x_out)
prediction = keras.layers.Reshape((-1,))(prediction)

model = keras.Model(inputs=x_inp, outputs=prediction)

model.compile(
    optimizer=keras.optimizers.Adam(lr=0.0001),
    loss=keras.losses.binary_crossentropy,
    metrics=["binary_accuracy", "AUC"],
)

init_train_metrics = model.evaluate(train_flow)
init_test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
    
history = model.fit(
    train_flow, epochs=epochs, validation_data=test_flow, verbose=2, shuffle=False
)
# Out:
# Using GCN (local pooling) filters...
# Using GCN (local pooling) filters...
# WARNING:tensorflow:From /Users/chaupham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 1/1 [==============================] - 0s 945us/step - loss: 7.6193 - binary_accuracy: 0.5002 - auc: 0.5004
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6199 - binary_accuracy: 0.5002 - auc: 0.5003
#
# Train Set Metrics of the initial (untrained) model:
# 	loss: 7.6193
# 	binary_accuracy: 0.5002
# 	auc: 0.5004
#
# Test Set Metrics of the initial (untrained) model:
# 	loss: 7.6199
# 	binary_accuracy: 0.5002
# 	auc: 0.5003
# Epoch 1/300
# 1/1 - 0s - loss: 7.6122 - binary_accuracy: 0.5006 - auc: 0.5008 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 2/300
# 1/1 - 0s - loss: 7.6097 - binary_accuracy: 0.5007 - auc: 0.5010 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 3/300
# 1/1 - 0s - loss: 7.6076 - binary_accuracy: 0.5009 - auc: 0.5011 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 4/300
# 1/1 - 0s - loss: 7.6091 - binary_accuracy: 0.5008 - auc: 0.5011 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 5/300
# 1/1 - 0s - loss: 7.6136 - binary_accuracy: 0.5006 - auc: 0.5007 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 6/300
# 1/1 - 0s - loss: 7.6132 - binary_accuracy: 0.5007 - auc: 0.5007 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 7/300
# 1/1 - 0s - loss: 7.6138 - binary_accuracy: 0.5006 - auc: 0.5006 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 8/300
# 1/1 - 0s - loss: 7.6105 - binary_accuracy: 0.5009 - auc: 0.5009 - val_loss: 7.6199 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 9/300
# 1/1 - 0s - loss: 7.6138 - binary_accuracy: 0.5006 - auc: 0.5007 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 10/300
# 1/1 - 0s - loss: 7.6053 - binary_accuracy: 0.5010 - auc: 0.5013 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 11/300
# 1/1 - 0s - loss: 7.6104 - binary_accuracy: 0.5009 - auc: 0.5009 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 12/300
# 1/1 - 0s - loss: 7.6084 - binary_accuracy: 0.5009 - auc: 0.5011 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 13/300
# 1/1 - 0s - loss: 7.6075 - binary_accuracy: 0.5010 - auc: 0.5011 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 14/300
# 1/1 - 0s - loss: 7.6090 - binary_accuracy: 0.5008 - auc: 0.5011 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 15/300
# 1/1 - 0s - loss: 7.6036 - binary_accuracy: 0.5013 - auc: 0.5014 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 16/300
# 1/1 - 0s - loss: 7.6037 - binary_accuracy: 0.5012 - auc: 0.5013 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 17/300
# 1/1 - 0s - loss: 7.6114 - binary_accuracy: 0.5007 - auc: 0.5008 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 18/300
# 1/1 - 0s - loss: 7.6098 - binary_accuracy: 0.5007 - auc: 0.5010 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 19/300
# 1/1 - 0s - loss: 7.6106 - binary_accuracy: 0.5007 - auc: 0.5009 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 20/300
# 1/1 - 0s - loss: 7.6066 - binary_accuracy: 0.5010 - auc: 0.5012 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 21/300
# 1/1 - 0s - loss: 7.6135 - binary_accuracy: 0.5005 - auc: 0.5008 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 22/300
# 1/1 - 0s - loss: 7.6075 - binary_accuracy: 0.5008 - auc: 0.5011 - val_loss: 7.6198 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 23/300
# 1/1 - 0s - loss: 7.6033 - binary_accuracy: 0.5011 - auc: 0.5013 - val_loss: 7.6194 - val_binary_accuracy: 0.5002 - val_auc: 0.5003
# Epoch 24/300
# 1/1 - 0s - loss: 7.6103 - binary_accuracy: 0.5008 - auc: 0.5010 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 25/300
# 1/1 - 1s - loss: 7.6026 - binary_accuracy: 0.5011 - auc: 0.5014 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 26/300
# 1/1 - 0s - loss: 7.6044 - binary_accuracy: 0.5012 - auc: 0.5014 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 27/300
# 1/1 - 0s - loss: 7.6060 - binary_accuracy: 0.5010 - auc: 0.5012 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 28/300
# 1/1 - 0s - loss: 7.5865 - binary_accuracy: 0.5015 - auc: 0.5019 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 29/300
# 1/1 - 1s - loss: 7.6025 - binary_accuracy: 0.5013 - auc: 0.5015 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 30/300
# 1/1 - 1s - loss: 7.6065 - binary_accuracy: 0.5010 - auc: 0.5011 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 31/300
# 1/1 - 1s - loss: 7.5997 - binary_accuracy: 0.5014 - auc: 0.5016 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 32/300
# 1/1 - 0s - loss: 7.6006 - binary_accuracy: 0.5014 - auc: 0.5015 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 33/300
# 1/1 - 1s - loss: 7.6052 - binary_accuracy: 0.5012 - auc: 0.5012 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 34/300
# 1/1 - 0s - loss: 7.6040 - binary_accuracy: 0.5012 - auc: 0.5013 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 35/300
# 1/1 - 0s - loss: 7.6064 - binary_accuracy: 0.5011 - auc: 0.5012 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 36/300
# 1/1 - 0s - loss: 7.6080 - binary_accuracy: 0.5009 - auc: 0.5011 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 37/300
# 1/1 - 0s - loss: 7.5897 - binary_accuracy: 0.5017 - auc: 0.5022 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 38/300
# 1/1 - 0s - loss: 7.6042 - binary_accuracy: 0.5013 - auc: 0.5013 - val_loss: 7.6189 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 39/300
# 1/1 - 0s - loss: 7.5943 - binary_accuracy: 0.5017 - auc: 0.5020 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 40/300
# 1/1 - 0s - loss: 7.6000 - binary_accuracy: 0.5013 - auc: 0.5016 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 41/300
# 1/1 - 0s - loss: 7.5882 - binary_accuracy: 0.5021 - auc: 0.5024 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 42/300
# 1/1 - 0s - loss: 7.6043 - binary_accuracy: 0.5012 - auc: 0.5013 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 43/300
# 1/1 - 0s - loss: 7.5936 - binary_accuracy: 0.5018 - auc: 0.5020 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 44/300
# 1/1 - 0s - loss: 7.6002 - binary_accuracy: 0.5015 - auc: 0.5016 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 45/300
# 1/1 - 0s - loss: 7.4983 - binary_accuracy: 0.5074 - auc: 0.5081 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 46/300
# 1/1 - 0s - loss: 7.5988 - binary_accuracy: 0.5014 - auc: 0.5017 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 47/300
# 1/1 - 0s - loss: 7.5990 - binary_accuracy: 0.5014 - auc: 0.5017 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 48/300
# 1/1 - 0s - loss: 7.5948 - binary_accuracy: 0.5015 - auc: 0.5019 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 49/300
# 1/1 - 0s - loss: 7.6012 - binary_accuracy: 0.5012 - auc: 0.5015 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 50/300
# 1/1 - 0s - loss: 7.5966 - binary_accuracy: 0.5015 - auc: 0.5017 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 51/300
# 1/1 - 0s - loss: 7.5636 - binary_accuracy: 0.5032 - auc: 0.5036 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 52/300
# 1/1 - 0s - loss: 7.5822 - binary_accuracy: 0.5023 - auc: 0.5027 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 53/300
# 1/1 - 0s - loss: 7.5522 - binary_accuracy: 0.5037 - auc: 0.5045 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 54/300
# 1/1 - 0s - loss: 7.5878 - binary_accuracy: 0.5022 - auc: 0.5022 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 55/300
# 1/1 - 0s - loss: 7.5774 - binary_accuracy: 0.5026 - auc: 0.5028 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 56/300
# 1/1 - 0s - loss: 7.5893 - binary_accuracy: 0.5020 - auc: 0.5022 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 57/300
# 1/1 - 0s - loss: 7.5895 - binary_accuracy: 0.5020 - auc: 0.5021 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 58/300
# 1/1 - 0s - loss: 7.5758 - binary_accuracy: 0.5022 - auc: 0.5030 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 59/300
# 1/1 - 0s - loss: 7.5780 - binary_accuracy: 0.5025 - auc: 0.5029 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 60/300
# 1/1 - 0s - loss: 7.5576 - binary_accuracy: 0.5036 - auc: 0.5041 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 61/300
# 1/1 - 0s - loss: 7.5800 - binary_accuracy: 0.5025 - auc: 0.5028 - val_loss: 7.6188 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 62/300
# 1/1 - 0s - loss: 7.5241 - binary_accuracy: 0.5054 - auc: 0.5062 - val_loss: 7.6183 - val_binary_accuracy: 0.5003 - val_auc: 0.5004
# Epoch 63/300
# 1/1 - 0s - loss: 7.5488 - binary_accuracy: 0.5038 - auc: 0.5046 - val_loss: 7.6177 - val_binary_accuracy: 0.5004 - val_auc: 0.5005
# Epoch 64/300
# 1/1 - 0s - loss: 7.4718 - binary_accuracy: 0.5082 - auc: 0.5092 - val_loss: 7.6175 - val_binary_accuracy: 0.5004 - val_auc: 0.5005
# Epoch 65/300
# 1/1 - 0s - loss: 7.5371 - binary_accuracy: 0.5047 - auc: 0.5056 - val_loss: 7.6169 - val_binary_accuracy: 0.5004 - val_auc: 0.5005
# Epoch 66/300
# 1/1 - 0s - loss: 7.5449 - binary_accuracy: 0.5047 - auc: 0.5048 - val_loss: 7.6163 - val_binary_accuracy: 0.5004 - val_auc: 0.5005
# Epoch 67/300
# 1/1 - 0s - loss: 7.5502 - binary_accuracy: 0.5042 - auc: 0.5046 - val_loss: 7.6156 - val_binary_accuracy: 0.5005 - val_auc: 0.5005
# Epoch 68/300
# 1/1 - 0s - loss: 7.3521 - binary_accuracy: 0.5158 - auc: 0.5173 - val_loss: 7.6126 - val_binary_accuracy: 0.5005 - val_auc: 0.5007
# Epoch 69/300
# 1/1 - 0s - loss: 7.5495 - binary_accuracy: 0.5040 - auc: 0.5045 - val_loss: 7.6117 - val_binary_accuracy: 0.5007 - val_auc: 0.5008
# Epoch 70/300
# 1/1 - 0s - loss: 6.3432 - binary_accuracy: 0.5538 - auc: 0.5581 - val_loss: 7.6111 - val_binary_accuracy: 0.5007 - val_auc: 0.5008
# Epoch 71/300
# 1/1 - 0s - loss: 6.9813 - binary_accuracy: 0.5314 - auc: 0.5354 - val_loss: 7.6108 - val_binary_accuracy: 0.5008 - val_auc: 0.5009
# Epoch 72/300
# 1/1 - 0s - loss: 7.4039 - binary_accuracy: 0.5120 - auc: 0.5138 - val_loss: 7.6102 - val_binary_accuracy: 0.5008 - val_auc: 0.5009
# Epoch 73/300
# 1/1 - 0s - loss: 7.4991 - binary_accuracy: 0.5068 - auc: 0.5077 - val_loss: 7.6095 - val_binary_accuracy: 0.5008 - val_auc: 0.5009
# Epoch 74/300
# 1/1 - 0s - loss: 5.8579 - binary_accuracy: 0.5683 - auc: 0.5749 - val_loss: 7.6076 - val_binary_accuracy: 0.5008 - val_auc: 0.5011
# Epoch 75/300
# 1/1 - 0s - loss: 7.3242 - binary_accuracy: 0.5173 - auc: 0.5189 - val_loss: 7.6066 - val_binary_accuracy: 0.5009 - val_auc: 0.5012
# Epoch 76/300
# 1/1 - 0s - loss: 7.3283 - binary_accuracy: 0.5167 - auc: 0.5181 - val_loss: 7.6052 - val_binary_accuracy: 0.5010 - val_auc: 0.5012
# Epoch 77/300
# 1/1 - 0s - loss: 7.3370 - binary_accuracy: 0.5148 - auc: 0.5179 - val_loss: 7.6022 - val_binary_accuracy: 0.5011 - val_auc: 0.5012
# Epoch 78/300
# 1/1 - 0s - loss: 6.3307 - binary_accuracy: 0.5524 - auc: 0.5611 - val_loss: 7.5966 - val_binary_accuracy: 0.5012 - val_auc: 0.5015
# Epoch 79/300
# 1/1 - 0s - loss: 7.4423 - binary_accuracy: 0.5099 - auc: 0.5112 - val_loss: 7.5927 - val_binary_accuracy: 0.5014 - val_auc: 0.5018
# Epoch 80/300
# 1/1 - 0s - loss: 7.3674 - binary_accuracy: 0.5132 - auc: 0.5160 - val_loss: 7.5858 - val_binary_accuracy: 0.5017 - val_auc: 0.5020
# Epoch 81/300
# 1/1 - 0s - loss: 7.2772 - binary_accuracy: 0.5192 - auc: 0.5212 - val_loss: 7.5768 - val_binary_accuracy: 0.5019 - val_auc: 0.5024
# Epoch 82/300
# 1/1 - 0s - loss: 7.3280 - binary_accuracy: 0.5162 - auc: 0.5180 - val_loss: 7.5661 - val_binary_accuracy: 0.5021 - val_auc: 0.5028
# Epoch 83/300
# 1/1 - 0s - loss: 7.3679 - binary_accuracy: 0.5140 - auc: 0.5159 - val_loss: 7.5512 - val_binary_accuracy: 0.5024 - val_auc: 0.5032
# Epoch 84/300
# 1/1 - 0s - loss: 5.9957 - binary_accuracy: 0.5760 - auc: 0.5854 - val_loss: 7.5451 - val_binary_accuracy: 0.5025 - val_auc: 0.5035
# Epoch 85/300
# 1/1 - 0s - loss: 5.2684 - binary_accuracy: 0.6009 - auc: 0.6112 - val_loss: 7.5391 - val_binary_accuracy: 0.5026 - val_auc: 0.5039
# Epoch 86/300
# 1/1 - 0s - loss: 7.1966 - binary_accuracy: 0.5207 - auc: 0.5250 - val_loss: 7.5300 - val_binary_accuracy: 0.5028 - val_auc: 0.5043
# Epoch 87/300
# 1/1 - 0s - loss: 6.9176 - binary_accuracy: 0.5365 - auc: 0.5415 - val_loss: 7.5164 - val_binary_accuracy: 0.5034 - val_auc: 0.5049
# Epoch 88/300
# 1/1 - 0s - loss: 7.1570 - binary_accuracy: 0.5240 - auc: 0.5271 - val_loss: 7.4994 - val_binary_accuracy: 0.5037 - val_auc: 0.5052
# Epoch 89/300
# 1/1 - 0s - loss: 6.6884 - binary_accuracy: 0.5487 - auc: 0.5554 - val_loss: 7.4658 - val_binary_accuracy: 0.5042 - val_auc: 0.5063
# Epoch 90/300
# 1/1 - 0s - loss: 6.7090 - binary_accuracy: 0.5472 - auc: 0.5536 - val_loss: 7.4095 - val_binary_accuracy: 0.5049 - val_auc: 0.5085
# Epoch 91/300
# 1/1 - 0s - loss: 6.5098 - binary_accuracy: 0.5556 - auc: 0.5632 - val_loss: 7.3162 - val_binary_accuracy: 0.5065 - val_auc: 0.5126
# Epoch 92/300
# 1/1 - 0s - loss: 6.2812 - binary_accuracy: 0.5667 - auc: 0.5770 - val_loss: 7.1556 - val_binary_accuracy: 0.5106 - val_auc: 0.5177
# Epoch 93/300
# 1/1 - 0s - loss: 5.3906 - binary_accuracy: 0.5935 - auc: 0.6043 - val_loss: 6.8299 - val_binary_accuracy: 0.5155 - val_auc: 0.5283
# Epoch 94/300
# 1/1 - 0s - loss: 5.4301 - binary_accuracy: 0.5864 - auc: 0.5944 - val_loss: 6.1449 - val_binary_accuracy: 0.5187 - val_auc: 0.5420
# Epoch 95/300
# 1/1 - 0s - loss: 5.6087 - binary_accuracy: 0.5949 - auc: 0.6076 - val_loss: 4.8783 - val_binary_accuracy: 0.5512 - val_auc: 0.5985
# Epoch 96/300
# 1/1 - 0s - loss: 5.7745 - binary_accuracy: 0.5606 - auc: 0.5684 - val_loss: 3.3040 - val_binary_accuracy: 0.5970 - val_auc: 0.6529
# Epoch 97/300
# 1/1 - 1s - loss: 5.4942 - binary_accuracy: 0.5885 - auc: 0.6039 - val_loss: 3.5357 - val_binary_accuracy: 0.5873 - val_auc: 0.6304
# Epoch 98/300
# 1/1 - 0s - loss: 5.6516 - binary_accuracy: 0.5544 - auc: 0.5614 - val_loss: 4.4208 - val_binary_accuracy: 0.5831 - val_auc: 0.6164
# Epoch 99/300
# 1/1 - 0s - loss: 5.0989 - binary_accuracy: 0.5738 - auc: 0.5913 - val_loss: 5.1204 - val_binary_accuracy: 0.5731 - val_auc: 0.5970
# Epoch 100/300
# 1/1 - 0s - loss: 5.3676 - binary_accuracy: 0.5761 - auc: 0.5868 - val_loss: 5.5514 - val_binary_accuracy: 0.5650 - val_auc: 0.5826
# Epoch 101/300
# 1/1 - 0s - loss: 5.4363 - binary_accuracy: 0.5993 - auc: 0.6126 - val_loss: 5.7502 - val_binary_accuracy: 0.5597 - val_auc: 0.5760
# Epoch 102/300
# 1/1 - 0s - loss: 5.0343 - binary_accuracy: 0.6025 - auc: 0.6161 - val_loss: 5.9139 - val_binary_accuracy: 0.5527 - val_auc: 0.5674
# Epoch 103/300
# 1/1 - 0s - loss: 5.1637 - binary_accuracy: 0.5972 - auc: 0.6102 - val_loss: 6.0913 - val_binary_accuracy: 0.5449 - val_auc: 0.5569
# Epoch 104/300
# 1/1 - 0s - loss: 5.3786 - binary_accuracy: 0.5645 - auc: 0.5732 - val_loss: 6.0822 - val_binary_accuracy: 0.5442 - val_auc: 0.5572
# Epoch 105/300
# 1/1 - 0s - loss: 6.0337 - binary_accuracy: 0.5686 - auc: 0.5796 - val_loss: 6.0227 - val_binary_accuracy: 0.5461 - val_auc: 0.5593
# Epoch 106/300
# 1/1 - 0s - loss: 5.0412 - binary_accuracy: 0.6068 - auc: 0.6191 - val_loss: 5.9415 - val_binary_accuracy: 0.5476 - val_auc: 0.5626
# Epoch 107/300
# 1/1 - 0s - loss: 5.3184 - binary_accuracy: 0.5993 - auc: 0.6140 - val_loss: 5.8052 - val_binary_accuracy: 0.5520 - val_auc: 0.5684
# Epoch 108/300
# 1/1 - 0s - loss: 6.3013 - binary_accuracy: 0.5639 - auc: 0.5758 - val_loss: 5.7877 - val_binary_accuracy: 0.5522 - val_auc: 0.5686
# Epoch 109/300
# 1/1 - 0s - loss: 5.2295 - binary_accuracy: 0.5858 - auc: 0.5971 - val_loss: 5.7850 - val_binary_accuracy: 0.5520 - val_auc: 0.5684
# Epoch 110/300
# 1/1 - 1s - loss: 5.3955 - binary_accuracy: 0.5723 - auc: 0.5817 - val_loss: 5.7878 - val_binary_accuracy: 0.5521 - val_auc: 0.5692
# Epoch 111/300
# 1/1 - 0s - loss: 5.1125 - binary_accuracy: 0.6018 - auc: 0.6150 - val_loss: 5.7135 - val_binary_accuracy: 0.5547 - val_auc: 0.5717
# Epoch 112/300
# 1/1 - 0s - loss: 5.2401 - binary_accuracy: 0.5986 - auc: 0.6132 - val_loss: 5.6664 - val_binary_accuracy: 0.5552 - val_auc: 0.5745
# Epoch 113/300
# 1/1 - 1s - loss: 5.1151 - binary_accuracy: 0.5868 - auc: 0.5988 - val_loss: 5.7314 - val_binary_accuracy: 0.5515 - val_auc: 0.5729
# Epoch 114/300
# 1/1 - 0s - loss: 4.9054 - binary_accuracy: 0.5990 - auc: 0.6132 - val_loss: 5.7496 - val_binary_accuracy: 0.5488 - val_auc: 0.5709
# Epoch 115/300
# 1/1 - 0s - loss: 5.0206 - binary_accuracy: 0.6092 - auc: 0.6208 - val_loss: 5.7300 - val_binary_accuracy: 0.5486 - val_auc: 0.5713
# Epoch 116/300
# 1/1 - 0s - loss: 4.9438 - binary_accuracy: 0.6084 - auc: 0.6258 - val_loss: 5.5918 - val_binary_accuracy: 0.5499 - val_auc: 0.5746
# Epoch 117/300
# 1/1 - 1s - loss: 5.4768 - binary_accuracy: 0.5735 - auc: 0.5806 - val_loss: 5.4320 - val_binary_accuracy: 0.5524 - val_auc: 0.5780
# Epoch 118/300
# 1/1 - 0s - loss: 4.7568 - binary_accuracy: 0.6096 - auc: 0.6279 - val_loss: 5.2746 - val_binary_accuracy: 0.5540 - val_auc: 0.5815
# Epoch 119/300
# 1/1 - 0s - loss: 4.3847 - binary_accuracy: 0.6169 - auc: 0.6384 - val_loss: 5.1262 - val_binary_accuracy: 0.5577 - val_auc: 0.5867
# Epoch 120/300
# 1/1 - 0s - loss: 5.1820 - binary_accuracy: 0.5965 - auc: 0.6091 - val_loss: 4.9459 - val_binary_accuracy: 0.5625 - val_auc: 0.5921
# Epoch 121/300
# 1/1 - 0s - loss: 4.6332 - binary_accuracy: 0.5966 - auc: 0.6130 - val_loss: 4.7455 - val_binary_accuracy: 0.5690 - val_auc: 0.5976
# Epoch 122/300
# 1/1 - 0s - loss: 5.2205 - binary_accuracy: 0.5880 - auc: 0.5957 - val_loss: 4.5967 - val_binary_accuracy: 0.5721 - val_auc: 0.6024
# Epoch 123/300
# 1/1 - 1s - loss: 4.6626 - binary_accuracy: 0.5987 - auc: 0.6112 - val_loss: 4.4795 - val_binary_accuracy: 0.5772 - val_auc: 0.6080
# Epoch 124/300
# 1/1 - 0s - loss: 4.8801 - binary_accuracy: 0.6013 - auc: 0.6156 - val_loss: 4.3624 - val_binary_accuracy: 0.5821 - val_auc: 0.6129
# Epoch 125/300
# 1/1 - 1s - loss: 5.0628 - binary_accuracy: 0.5885 - auc: 0.5977 - val_loss: 4.2613 - val_binary_accuracy: 0.5872 - val_auc: 0.6186
# Epoch 126/300
# 1/1 - 0s - loss: 4.3617 - binary_accuracy: 0.6252 - auc: 0.6446 - val_loss: 4.1702 - val_binary_accuracy: 0.5912 - val_auc: 0.6218
# Epoch 127/300
# 1/1 - 0s - loss: 4.7782 - binary_accuracy: 0.5991 - auc: 0.6177 - val_loss: 4.0922 - val_binary_accuracy: 0.5956 - val_auc: 0.6270
# Epoch 128/300
# 1/1 - 0s - loss: 4.7346 - binary_accuracy: 0.6011 - auc: 0.6190 - val_loss: 4.0425 - val_binary_accuracy: 0.5994 - val_auc: 0.6296
# Epoch 129/300
# 1/1 - 0s - loss: 4.5379 - binary_accuracy: 0.6184 - auc: 0.6365 - val_loss: 4.0167 - val_binary_accuracy: 0.6013 - val_auc: 0.6309
# Epoch 130/300
# 1/1 - 0s - loss: 4.3637 - binary_accuracy: 0.6289 - auc: 0.6444 - val_loss: 4.0230 - val_binary_accuracy: 0.6011 - val_auc: 0.6308
# Epoch 131/300
# 1/1 - 0s - loss: 4.6876 - binary_accuracy: 0.6053 - auc: 0.6209 - val_loss: 4.0547 - val_binary_accuracy: 0.6012 - val_auc: 0.6308
# Epoch 132/300
# 1/1 - 1s - loss: 4.3378 - binary_accuracy: 0.6281 - auc: 0.6459 - val_loss: 4.0980 - val_binary_accuracy: 0.6002 - val_auc: 0.6297
# Epoch 133/300
# 1/1 - 0s - loss: 4.4719 - binary_accuracy: 0.6254 - auc: 0.6455 - val_loss: 4.1472 - val_binary_accuracy: 0.5998 - val_auc: 0.6278
# Epoch 134/300
# 1/1 - 1s - loss: 5.1691 - binary_accuracy: 0.5996 - auc: 0.6176 - val_loss: 4.2017 - val_binary_accuracy: 0.5988 - val_auc: 0.6264
# Epoch 135/300
# 1/1 - 0s - loss: 4.5800 - binary_accuracy: 0.6092 - auc: 0.6253 - val_loss: 4.2445 - val_binary_accuracy: 0.5975 - val_auc: 0.6246
# Epoch 136/300
# 1/1 - 1s - loss: 6.1200 - binary_accuracy: 0.5687 - auc: 0.5784 - val_loss: 4.2991 - val_binary_accuracy: 0.5964 - val_auc: 0.6227
# Epoch 137/300
# 1/1 - 0s - loss: 4.7560 - binary_accuracy: 0.6048 - auc: 0.6193 - val_loss: 4.3723 - val_binary_accuracy: 0.5961 - val_auc: 0.6216
# Epoch 138/300
# 1/1 - 0s - loss: 4.5054 - binary_accuracy: 0.6186 - auc: 0.6357 - val_loss: 4.4310 - val_binary_accuracy: 0.5953 - val_auc: 0.6192
# Epoch 139/300
# 1/1 - 1s - loss: 4.6776 - binary_accuracy: 0.6144 - auc: 0.6296 - val_loss: 4.4544 - val_binary_accuracy: 0.5945 - val_auc: 0.6188
# Epoch 140/300
# 1/1 - 0s - loss: 4.5520 - binary_accuracy: 0.6144 - auc: 0.6301 - val_loss: 4.4622 - val_binary_accuracy: 0.5939 - val_auc: 0.6187
# Epoch 141/300
# 1/1 - 0s - loss: 5.6163 - binary_accuracy: 0.5842 - auc: 0.5992 - val_loss: 4.4856 - val_binary_accuracy: 0.5944 - val_auc: 0.6180
# Epoch 142/300
# 1/1 - 0s - loss: 4.5835 - binary_accuracy: 0.6108 - auc: 0.6285 - val_loss: 4.4994 - val_binary_accuracy: 0.5935 - val_auc: 0.6174
# Epoch 143/300
# 1/1 - 1s - loss: 4.4643 - binary_accuracy: 0.6199 - auc: 0.6349 - val_loss: 4.5042 - val_binary_accuracy: 0.5936 - val_auc: 0.6175
# Epoch 144/300
# 1/1 - 0s - loss: 4.7702 - binary_accuracy: 0.6055 - auc: 0.6198 - val_loss: 4.5071 - val_binary_accuracy: 0.5935 - val_auc: 0.6174
# Epoch 145/300
# 1/1 - 1s - loss: 4.6583 - binary_accuracy: 0.6102 - auc: 0.6221 - val_loss: 4.5054 - val_binary_accuracy: 0.5933 - val_auc: 0.6176
# Epoch 146/300
# 1/1 - 1s - loss: 4.3584 - binary_accuracy: 0.6242 - auc: 0.6422 - val_loss: 4.5081 - val_binary_accuracy: 0.5936 - val_auc: 0.6175
# Epoch 147/300
# 1/1 - 1s - loss: 4.7082 - binary_accuracy: 0.6095 - auc: 0.6256 - val_loss: 4.5063 - val_binary_accuracy: 0.5937 - val_auc: 0.6175
# Epoch 148/300
# 1/1 - 1s - loss: 4.4769 - binary_accuracy: 0.6166 - auc: 0.6315 - val_loss: 4.4946 - val_binary_accuracy: 0.5933 - val_auc: 0.6176
# Epoch 149/300
# 1/1 - 0s - loss: 4.6941 - binary_accuracy: 0.6063 - auc: 0.6233 - val_loss: 4.4660 - val_binary_accuracy: 0.5944 - val_auc: 0.6182
# Epoch 150/300
# 1/1 - 1s - loss: 4.6254 - binary_accuracy: 0.6101 - auc: 0.6259 - val_loss: 4.4441 - val_binary_accuracy: 0.5941 - val_auc: 0.6188
# Epoch 151/300
# 1/1 - 1s - loss: 4.5677 - binary_accuracy: 0.6165 - auc: 0.6309 - val_loss: 4.4249 - val_binary_accuracy: 0.5950 - val_auc: 0.6191
# Epoch 152/300
# 1/1 - 1s - loss: 4.5920 - binary_accuracy: 0.6062 - auc: 0.6228 - val_loss: 4.4015 - val_binary_accuracy: 0.5956 - val_auc: 0.6201
# Epoch 153/300
# 1/1 - 1s - loss: 4.8807 - binary_accuracy: 0.5999 - auc: 0.6153 - val_loss: 4.3555 - val_binary_accuracy: 0.5958 - val_auc: 0.6214
# Epoch 154/300
# 1/1 - 0s - loss: 4.3670 - binary_accuracy: 0.6154 - auc: 0.6343 - val_loss: 4.2923 - val_binary_accuracy: 0.5961 - val_auc: 0.6225
# Epoch 155/300
# 1/1 - 0s - loss: 4.6608 - binary_accuracy: 0.5996 - auc: 0.6174 - val_loss: 4.2329 - val_binary_accuracy: 0.5961 - val_auc: 0.6240
# Epoch 156/300
# 1/1 - 0s - loss: 4.4462 - binary_accuracy: 0.6208 - auc: 0.6380 - val_loss: 4.1709 - val_binary_accuracy: 0.5978 - val_auc: 0.6265
# Epoch 157/300
# 1/1 - 0s - loss: 4.3902 - binary_accuracy: 0.6066 - auc: 0.6235 - val_loss: 4.1110 - val_binary_accuracy: 0.5989 - val_auc: 0.6282
# Epoch 158/300
# 1/1 - 0s - loss: 5.4483 - binary_accuracy: 0.5906 - auc: 0.6040 - val_loss: 4.0429 - val_binary_accuracy: 0.5994 - val_auc: 0.6302
# Epoch 159/300
# 1/1 - 1s - loss: 4.3640 - binary_accuracy: 0.6179 - auc: 0.6391 - val_loss: 3.9839 - val_binary_accuracy: 0.5997 - val_auc: 0.6317
# Epoch 160/300
# 1/1 - 0s - loss: 4.7854 - binary_accuracy: 0.5924 - auc: 0.6087 - val_loss: 3.9416 - val_binary_accuracy: 0.6001 - val_auc: 0.6320
# Epoch 161/300
# 1/1 - 0s - loss: 4.4597 - binary_accuracy: 0.6167 - auc: 0.6352 - val_loss: 3.9222 - val_binary_accuracy: 0.6006 - val_auc: 0.6324
# Epoch 162/300
# 1/1 - 0s - loss: 4.4648 - binary_accuracy: 0.6041 - auc: 0.6228 - val_loss: 3.9080 - val_binary_accuracy: 0.6010 - val_auc: 0.6328
# Epoch 163/300
# 1/1 - 0s - loss: 5.1277 - binary_accuracy: 0.6108 - auc: 0.6273 - val_loss: 3.8934 - val_binary_accuracy: 0.6016 - val_auc: 0.6337
# Epoch 164/300
# 1/1 - 1s - loss: 4.4064 - binary_accuracy: 0.6268 - auc: 0.6450 - val_loss: 3.8855 - val_binary_accuracy: 0.6005 - val_auc: 0.6331
# Epoch 165/300
# 1/1 - 1s - loss: 5.3111 - binary_accuracy: 0.5705 - auc: 0.5785 - val_loss: 3.8832 - val_binary_accuracy: 0.6000 - val_auc: 0.6328
# Epoch 166/300
# 1/1 - 0s - loss: 4.6146 - binary_accuracy: 0.6005 - auc: 0.6143 - val_loss: 3.8809 - val_binary_accuracy: 0.5999 - val_auc: 0.6325
# Epoch 167/300
# 1/1 - 1s - loss: 4.6277 - binary_accuracy: 0.6024 - auc: 0.6192 - val_loss: 3.8806 - val_binary_accuracy: 0.5985 - val_auc: 0.6324
# Epoch 168/300
# 1/1 - 0s - loss: 4.3562 - binary_accuracy: 0.6126 - auc: 0.6306 - val_loss: 3.8829 - val_binary_accuracy: 0.5978 - val_auc: 0.6313
# Epoch 169/300
# 1/1 - 0s - loss: 5.2454 - binary_accuracy: 0.6017 - auc: 0.6110 - val_loss: 3.8892 - val_binary_accuracy: 0.5963 - val_auc: 0.6303
# Epoch 170/300
# 1/1 - 0s - loss: 4.3990 - binary_accuracy: 0.6228 - auc: 0.6473 - val_loss: 3.8923 - val_binary_accuracy: 0.5954 - val_auc: 0.6301
# Epoch 171/300
# 1/1 - 0s - loss: 4.4713 - binary_accuracy: 0.6105 - auc: 0.6311 - val_loss: 3.8926 - val_binary_accuracy: 0.5952 - val_auc: 0.6300
# Epoch 172/300
# 1/1 - 0s - loss: 4.2438 - binary_accuracy: 0.6256 - auc: 0.6451 - val_loss: 3.8904 - val_binary_accuracy: 0.5951 - val_auc: 0.6299
# Epoch 173/300
# 1/1 - 0s - loss: 5.1512 - binary_accuracy: 0.6037 - auc: 0.6215 - val_loss: 3.8770 - val_binary_accuracy: 0.5958 - val_auc: 0.6303
# Epoch 174/300
# 1/1 - 0s - loss: 4.6290 - binary_accuracy: 0.6080 - auc: 0.6297 - val_loss: 3.8635 - val_binary_accuracy: 0.5979 - val_auc: 0.6314
# Epoch 175/300
# 1/1 - 0s - loss: 4.3110 - binary_accuracy: 0.6224 - auc: 0.6440 - val_loss: 3.8571 - val_binary_accuracy: 0.5986 - val_auc: 0.6326
# Epoch 176/300
# 1/1 - 0s - loss: 4.8745 - binary_accuracy: 0.6015 - auc: 0.6121 - val_loss: 3.8606 - val_binary_accuracy: 0.6007 - val_auc: 0.6338
# Epoch 177/300
# 1/1 - 0s - loss: 4.9979 - binary_accuracy: 0.5906 - auc: 0.5989 - val_loss: 3.8751 - val_binary_accuracy: 0.6006 - val_auc: 0.6330
# Epoch 178/300
# 1/1 - 0s - loss: 4.5115 - binary_accuracy: 0.6083 - auc: 0.6255 - val_loss: 3.8969 - val_binary_accuracy: 0.6000 - val_auc: 0.6324
# Epoch 179/300
# 1/1 - 0s - loss: 4.4590 - binary_accuracy: 0.6020 - auc: 0.6234 - val_loss: 3.9241 - val_binary_accuracy: 0.5986 - val_auc: 0.6318
# Epoch 180/300
# 1/1 - 0s - loss: 6.0052 - binary_accuracy: 0.5761 - auc: 0.5857 - val_loss: 3.9411 - val_binary_accuracy: 0.5987 - val_auc: 0.6315
# Epoch 181/300
# 1/1 - 0s - loss: 4.8659 - binary_accuracy: 0.5993 - auc: 0.6158 - val_loss: 3.9753 - val_binary_accuracy: 0.5985 - val_auc: 0.6308
# Epoch 182/300
# 1/1 - 0s - loss: 4.5772 - binary_accuracy: 0.6064 - auc: 0.6277 - val_loss: 4.0184 - val_binary_accuracy: 0.5986 - val_auc: 0.6294
# Epoch 183/300
# 1/1 - 0s - loss: 4.4466 - binary_accuracy: 0.6087 - auc: 0.6285 - val_loss: 4.0462 - val_binary_accuracy: 0.5977 - val_auc: 0.6283
# Epoch 184/300
# 1/1 - 0s - loss: 4.7257 - binary_accuracy: 0.6077 - auc: 0.6308 - val_loss: 4.0933 - val_binary_accuracy: 0.5970 - val_auc: 0.6273
# Epoch 185/300
# 1/1 - 0s - loss: 4.4954 - binary_accuracy: 0.6079 - auc: 0.6259 - val_loss: 4.1337 - val_binary_accuracy: 0.5963 - val_auc: 0.6258
# Epoch 186/300
# 1/1 - 0s - loss: 4.1920 - binary_accuracy: 0.6079 - auc: 0.6296 - val_loss: 4.1762 - val_binary_accuracy: 0.5953 - val_auc: 0.6235
# Epoch 187/300
# 1/1 - 0s - loss: 4.9062 - binary_accuracy: 0.6003 - auc: 0.6201 - val_loss: 4.2265 - val_binary_accuracy: 0.5947 - val_auc: 0.6220
# Epoch 188/300
# 1/1 - 0s - loss: 4.3293 - binary_accuracy: 0.6038 - auc: 0.6240 - val_loss: 4.2645 - val_binary_accuracy: 0.5941 - val_auc: 0.6209
# Epoch 189/300
# 1/1 - 0s - loss: 4.5614 - binary_accuracy: 0.6227 - auc: 0.6360 - val_loss: 4.3020 - val_binary_accuracy: 0.5936 - val_auc: 0.6198
# Epoch 190/300
# 1/1 - 0s - loss: 5.3933 - binary_accuracy: 0.5968 - auc: 0.6126 - val_loss: 4.3006 - val_binary_accuracy: 0.5935 - val_auc: 0.6198
# Epoch 191/300
# 1/1 - 0s - loss: 4.6162 - binary_accuracy: 0.5926 - auc: 0.6084 - val_loss: 4.2778 - val_binary_accuracy: 0.5943 - val_auc: 0.6202
# Epoch 192/300
# 1/1 - 0s - loss: 4.3577 - binary_accuracy: 0.6095 - auc: 0.6303 - val_loss: 4.2614 - val_binary_accuracy: 0.5940 - val_auc: 0.6206
# Epoch 193/300
# 1/1 - 0s - loss: 4.3402 - binary_accuracy: 0.6006 - auc: 0.6225 - val_loss: 4.2548 - val_binary_accuracy: 0.5941 - val_auc: 0.6208
# Epoch 194/300
# 1/1 - 0s - loss: 4.6829 - binary_accuracy: 0.6008 - auc: 0.6176 - val_loss: 4.2555 - val_binary_accuracy: 0.5940 - val_auc: 0.6207
# Epoch 195/300
# 1/1 - 0s - loss: 4.8616 - binary_accuracy: 0.5959 - auc: 0.6118 - val_loss: 4.2296 - val_binary_accuracy: 0.5938 - val_auc: 0.6214
# Epoch 196/300
# 1/1 - 0s - loss: 4.6472 - binary_accuracy: 0.5976 - auc: 0.6161 - val_loss: 4.2057 - val_binary_accuracy: 0.5943 - val_auc: 0.6218
# Epoch 197/300
# 1/1 - 0s - loss: 4.5965 - binary_accuracy: 0.6111 - auc: 0.6370 - val_loss: 4.2179 - val_binary_accuracy: 0.5941 - val_auc: 0.6217
# Epoch 198/300
# 1/1 - 0s - loss: 4.4664 - binary_accuracy: 0.6246 - auc: 0.6422 - val_loss: 4.2402 - val_binary_accuracy: 0.5938 - val_auc: 0.6209
# Epoch 199/300
# 1/1 - 0s - loss: 4.1388 - binary_accuracy: 0.6080 - auc: 0.6338 - val_loss: 4.2623 - val_binary_accuracy: 0.5943 - val_auc: 0.6202
# Epoch 200/300
# 1/1 - 0s - loss: 4.7500 - binary_accuracy: 0.6027 - auc: 0.6184 - val_loss: 4.2573 - val_binary_accuracy: 0.5941 - val_auc: 0.6204
# Epoch 201/300
# 1/1 - 0s - loss: 5.5625 - binary_accuracy: 0.5898 - auc: 0.6040 - val_loss: 4.2316 - val_binary_accuracy: 0.5939 - val_auc: 0.6214
# Epoch 202/300
# 1/1 - 0s - loss: 4.7313 - binary_accuracy: 0.5919 - auc: 0.6082 - val_loss: 4.2189 - val_binary_accuracy: 0.5939 - val_auc: 0.6217
# Epoch 203/300
# 1/1 - 0s - loss: 4.5721 - binary_accuracy: 0.6047 - auc: 0.6242 - val_loss: 4.2185 - val_binary_accuracy: 0.5938 - val_auc: 0.6216
# Epoch 204/300
# 1/1 - 0s - loss: 4.8885 - binary_accuracy: 0.6021 - auc: 0.6172 - val_loss: 4.2236 - val_binary_accuracy: 0.5937 - val_auc: 0.6213
# Epoch 205/300
# 1/1 - 0s - loss: 5.2308 - binary_accuracy: 0.6027 - auc: 0.6166 - val_loss: 4.2221 - val_binary_accuracy: 0.5936 - val_auc: 0.6212
# Epoch 206/300
# 1/1 - 0s - loss: 5.0101 - binary_accuracy: 0.5902 - auc: 0.6037 - val_loss: 4.2060 - val_binary_accuracy: 0.5938 - val_auc: 0.6215
# Epoch 207/300
# 1/1 - 0s - loss: 5.3780 - binary_accuracy: 0.5985 - auc: 0.6116 - val_loss: 4.1614 - val_binary_accuracy: 0.5939 - val_auc: 0.6228
# Epoch 208/300
# 1/1 - 0s - loss: 5.1093 - binary_accuracy: 0.5962 - auc: 0.6049 - val_loss: 4.1291 - val_binary_accuracy: 0.5946 - val_auc: 0.6243
# Epoch 209/300
# 1/1 - 0s - loss: 4.9872 - binary_accuracy: 0.5869 - auc: 0.5956 - val_loss: 4.0972 - val_binary_accuracy: 0.5954 - val_auc: 0.6255
# Epoch 210/300
# 1/1 - 0s - loss: 4.2912 - binary_accuracy: 0.6058 - auc: 0.6254 - val_loss: 4.0623 - val_binary_accuracy: 0.5960 - val_auc: 0.6264
# Epoch 211/300
# 1/1 - 0s - loss: 4.4631 - binary_accuracy: 0.6065 - auc: 0.6244 - val_loss: 4.0248 - val_binary_accuracy: 0.5965 - val_auc: 0.6277
# Epoch 212/300
# 1/1 - 0s - loss: 4.4200 - binary_accuracy: 0.6092 - auc: 0.6257 - val_loss: 3.9837 - val_binary_accuracy: 0.5973 - val_auc: 0.6290
# Epoch 213/300
# 1/1 - 0s - loss: 4.5515 - binary_accuracy: 0.6104 - auc: 0.6315 - val_loss: 3.9551 - val_binary_accuracy: 0.5976 - val_auc: 0.6295
# Epoch 214/300
# 1/1 - 0s - loss: 4.3723 - binary_accuracy: 0.6193 - auc: 0.6360 - val_loss: 3.9183 - val_binary_accuracy: 0.5980 - val_auc: 0.6304
# Epoch 215/300
# 1/1 - 0s - loss: 4.4271 - binary_accuracy: 0.6073 - auc: 0.6274 - val_loss: 3.8934 - val_binary_accuracy: 0.5979 - val_auc: 0.6313
# Epoch 216/300
# 1/1 - 0s - loss: 5.3197 - binary_accuracy: 0.5787 - auc: 0.5866 - val_loss: 3.8700 - val_binary_accuracy: 0.5977 - val_auc: 0.6317
# Epoch 217/300
# 1/1 - 0s - loss: 5.2519 - binary_accuracy: 0.5984 - auc: 0.6145 - val_loss: 3.8389 - val_binary_accuracy: 0.5988 - val_auc: 0.6327
# Epoch 218/300
# 1/1 - 0s - loss: 4.4288 - binary_accuracy: 0.6111 - auc: 0.6305 - val_loss: 3.8129 - val_binary_accuracy: 0.5997 - val_auc: 0.6331
# Epoch 219/300
# 1/1 - 0s - loss: 4.3913 - binary_accuracy: 0.6056 - auc: 0.6270 - val_loss: 3.7997 - val_binary_accuracy: 0.5998 - val_auc: 0.6338
# Epoch 220/300
# 1/1 - 0s - loss: 4.2961 - binary_accuracy: 0.6200 - auc: 0.6408 - val_loss: 3.7887 - val_binary_accuracy: 0.6002 - val_auc: 0.6343
# Epoch 221/300
# 1/1 - 0s - loss: 4.3908 - binary_accuracy: 0.6113 - auc: 0.6365 - val_loss: 3.7856 - val_binary_accuracy: 0.6002 - val_auc: 0.6345
# Epoch 222/300
# 1/1 - 0s - loss: 4.0233 - binary_accuracy: 0.6034 - auc: 0.6250 - val_loss: 3.7793 - val_binary_accuracy: 0.6008 - val_auc: 0.6343
# Epoch 223/300
# 1/1 - 0s - loss: 4.7300 - binary_accuracy: 0.6003 - auc: 0.6225 - val_loss: 3.7766 - val_binary_accuracy: 0.6007 - val_auc: 0.6344
# Epoch 224/300
# 1/1 - 0s - loss: 4.4972 - binary_accuracy: 0.5940 - auc: 0.6096 - val_loss: 3.7733 - val_binary_accuracy: 0.6006 - val_auc: 0.6344
# Epoch 225/300
# 1/1 - 0s - loss: 4.8085 - binary_accuracy: 0.6039 - auc: 0.6273 - val_loss: 3.7742 - val_binary_accuracy: 0.6003 - val_auc: 0.6342
# Epoch 226/300
# 1/1 - 0s - loss: 4.4313 - binary_accuracy: 0.6183 - auc: 0.6356 - val_loss: 3.7789 - val_binary_accuracy: 0.6000 - val_auc: 0.6338
# Epoch 227/300
# 1/1 - 0s - loss: 5.1975 - binary_accuracy: 0.6007 - auc: 0.6188 - val_loss: 3.7723 - val_binary_accuracy: 0.6000 - val_auc: 0.6340
# Epoch 228/300
# 1/1 - 0s - loss: 4.5037 - binary_accuracy: 0.6069 - auc: 0.6246 - val_loss: 3.7666 - val_binary_accuracy: 0.6000 - val_auc: 0.6342
# Epoch 229/300
# 1/1 - 0s - loss: 5.1570 - binary_accuracy: 0.6001 - auc: 0.6149 - val_loss: 3.7557 - val_binary_accuracy: 0.6004 - val_auc: 0.6342
# Epoch 230/300
# 1/1 - 0s - loss: 4.4410 - binary_accuracy: 0.6083 - auc: 0.6308 - val_loss: 3.7482 - val_binary_accuracy: 0.6003 - val_auc: 0.6337
# Epoch 231/300
# 1/1 - 0s - loss: 4.5195 - binary_accuracy: 0.6127 - auc: 0.6337 - val_loss: 3.7448 - val_binary_accuracy: 0.6003 - val_auc: 0.6337
# Epoch 232/300
# 1/1 - 0s - loss: 4.5602 - binary_accuracy: 0.6031 - auc: 0.6240 - val_loss: 3.7440 - val_binary_accuracy: 0.6006 - val_auc: 0.6342
# Epoch 233/300
# 1/1 - 0s - loss: 4.8146 - binary_accuracy: 0.6067 - auc: 0.6260 - val_loss: 3.7462 - val_binary_accuracy: 0.6000 - val_auc: 0.6341
# Epoch 234/300
# 1/1 - 0s - loss: 4.3901 - binary_accuracy: 0.6040 - auc: 0.6242 - val_loss: 3.7500 - val_binary_accuracy: 0.6000 - val_auc: 0.6341
# Epoch 235/300
# 1/1 - 0s - loss: 4.3707 - binary_accuracy: 0.5985 - auc: 0.6180 - val_loss: 3.7514 - val_binary_accuracy: 0.5999 - val_auc: 0.6337
# Epoch 236/300
# 1/1 - 0s - loss: 4.5682 - binary_accuracy: 0.6038 - auc: 0.6238 - val_loss: 3.7547 - val_binary_accuracy: 0.5991 - val_auc: 0.6334
# Epoch 237/300
# 1/1 - 0s - loss: 5.7495 - binary_accuracy: 0.5820 - auc: 0.5940 - val_loss: 3.7472 - val_binary_accuracy: 0.5994 - val_auc: 0.6334
# Epoch 238/300
# 1/1 - 0s - loss: 4.5193 - binary_accuracy: 0.6147 - auc: 0.6325 - val_loss: 3.7346 - val_binary_accuracy: 0.5994 - val_auc: 0.6338
# Epoch 239/300
# 1/1 - 0s - loss: 4.4404 - binary_accuracy: 0.6147 - auc: 0.6311 - val_loss: 3.7236 - val_binary_accuracy: 0.5994 - val_auc: 0.6338
# Epoch 240/300
# 1/1 - 0s - loss: 5.8719 - binary_accuracy: 0.5787 - auc: 0.5902 - val_loss: 3.7087 - val_binary_accuracy: 0.5994 - val_auc: 0.6335
# Epoch 241/300
# 1/1 - 0s - loss: 5.7748 - binary_accuracy: 0.5811 - auc: 0.5966 - val_loss: 3.6915 - val_binary_accuracy: 0.5990 - val_auc: 0.6330
# Epoch 242/300
# 1/1 - 0s - loss: 4.5830 - binary_accuracy: 0.6147 - auc: 0.6336 - val_loss: 3.6843 - val_binary_accuracy: 0.5976 - val_auc: 0.6324
# Epoch 243/300
# 1/1 - 0s - loss: 4.6517 - binary_accuracy: 0.6021 - auc: 0.6176 - val_loss: 3.6829 - val_binary_accuracy: 0.5963 - val_auc: 0.6322
# Epoch 244/300
# 1/1 - 0s - loss: 5.2097 - binary_accuracy: 0.5769 - auc: 0.5863 - val_loss: 3.6991 - val_binary_accuracy: 0.5944 - val_auc: 0.6309
# Epoch 245/300
# 1/1 - 0s - loss: 4.9667 - binary_accuracy: 0.6030 - auc: 0.6232 - val_loss: 3.7024 - val_binary_accuracy: 0.5933 - val_auc: 0.6289
# Epoch 246/300
# 1/1 - 0s - loss: 4.5671 - binary_accuracy: 0.6136 - auc: 0.6310 - val_loss: 3.7151 - val_binary_accuracy: 0.5931 - val_auc: 0.6291
# Epoch 247/300
# 1/1 - 0s - loss: 5.4461 - binary_accuracy: 0.5946 - auc: 0.6060 - val_loss: 3.7295 - val_binary_accuracy: 0.5921 - val_auc: 0.6295
# Epoch 248/300
# 1/1 - 0s - loss: 4.5943 - binary_accuracy: 0.6026 - auc: 0.6216 - val_loss: 3.7310 - val_binary_accuracy: 0.5918 - val_auc: 0.6287
# Epoch 249/300
# 1/1 - 0s - loss: 4.1197 - binary_accuracy: 0.6331 - auc: 0.6527 - val_loss: 3.7333 - val_binary_accuracy: 0.5928 - val_auc: 0.6290
# Epoch 250/300
# 1/1 - 0s - loss: 4.3611 - binary_accuracy: 0.6092 - auc: 0.6279 - val_loss: 3.7224 - val_binary_accuracy: 0.5923 - val_auc: 0.6301
# Epoch 251/300
# 1/1 - 0s - loss: 4.2847 - binary_accuracy: 0.6055 - auc: 0.6228 - val_loss: 3.7184 - val_binary_accuracy: 0.5916 - val_auc: 0.6309
# Epoch 252/300
# 1/1 - 0s - loss: 4.6127 - binary_accuracy: 0.6126 - auc: 0.6324 - val_loss: 3.7066 - val_binary_accuracy: 0.5931 - val_auc: 0.6320
# Epoch 253/300
# 1/1 - 0s - loss: 4.3984 - binary_accuracy: 0.6243 - auc: 0.6466 - val_loss: 3.6845 - val_binary_accuracy: 0.5945 - val_auc: 0.6343
# Epoch 254/300
# 1/1 - 0s - loss: 4.3878 - binary_accuracy: 0.6189 - auc: 0.6381 - val_loss: 3.6609 - val_binary_accuracy: 0.5971 - val_auc: 0.6360
# Epoch 255/300
# 1/1 - 0s - loss: 4.7085 - binary_accuracy: 0.5976 - auc: 0.6109 - val_loss: 3.6437 - val_binary_accuracy: 0.5978 - val_auc: 0.6364
# Epoch 256/300
# 1/1 - 0s - loss: 4.4759 - binary_accuracy: 0.6122 - auc: 0.6297 - val_loss: 3.6224 - val_binary_accuracy: 0.5980 - val_auc: 0.6369
# Epoch 257/300
# 1/1 - 0s - loss: 4.2329 - binary_accuracy: 0.6293 - auc: 0.6477 - val_loss: 3.6045 - val_binary_accuracy: 0.5992 - val_auc: 0.6373
# Epoch 258/300
# 1/1 - 0s - loss: 5.5167 - binary_accuracy: 0.5781 - auc: 0.5869 - val_loss: 3.5990 - val_binary_accuracy: 0.6003 - val_auc: 0.6370
# Epoch 259/300
# 1/1 - 0s - loss: 4.3220 - binary_accuracy: 0.6238 - auc: 0.6441 - val_loss: 3.5886 - val_binary_accuracy: 0.6006 - val_auc: 0.6370
# Epoch 260/300
# 1/1 - 0s - loss: 5.0601 - binary_accuracy: 0.5800 - auc: 0.5882 - val_loss: 3.5903 - val_binary_accuracy: 0.5987 - val_auc: 0.6349
# Epoch 261/300
# 1/1 - 0s - loss: 4.3273 - binary_accuracy: 0.6232 - auc: 0.6425 - val_loss: 3.5879 - val_binary_accuracy: 0.5972 - val_auc: 0.6332
# Epoch 262/300
# 1/1 - 0s - loss: 4.5258 - binary_accuracy: 0.6092 - auc: 0.6233 - val_loss: 3.5909 - val_binary_accuracy: 0.5958 - val_auc: 0.6320
# Epoch 263/300
# 1/1 - 0s - loss: 6.2555 - binary_accuracy: 0.5621 - auc: 0.5713 - val_loss: 3.6014 - val_binary_accuracy: 0.5963 - val_auc: 0.6312
# Epoch 264/300
# 1/1 - 0s - loss: 4.2406 - binary_accuracy: 0.6309 - auc: 0.6500 - val_loss: 3.5854 - val_binary_accuracy: 0.5971 - val_auc: 0.6317
# Epoch 265/300
# 1/1 - 0s - loss: 4.1773 - binary_accuracy: 0.6158 - auc: 0.6351 - val_loss: 3.5982 - val_binary_accuracy: 0.5986 - val_auc: 0.6322
# Epoch 266/300
# 1/1 - 0s - loss: 4.0311 - binary_accuracy: 0.6219 - auc: 0.6453 - val_loss: 3.6033 - val_binary_accuracy: 0.5982 - val_auc: 0.6316
# Epoch 267/300
# 1/1 - 0s - loss: 4.5221 - binary_accuracy: 0.6154 - auc: 0.6347 - val_loss: 3.6171 - val_binary_accuracy: 0.5978 - val_auc: 0.6308
# Epoch 268/300
# 1/1 - 0s - loss: 4.6618 - binary_accuracy: 0.6015 - auc: 0.6214 - val_loss: 3.6375 - val_binary_accuracy: 0.5961 - val_auc: 0.6300
# Epoch 269/300
# 1/1 - 0s - loss: 4.2715 - binary_accuracy: 0.6188 - auc: 0.6381 - val_loss: 3.6625 - val_binary_accuracy: 0.5949 - val_auc: 0.6293
# Epoch 270/300
# 1/1 - 0s - loss: 4.3344 - binary_accuracy: 0.6120 - auc: 0.6305 - val_loss: 3.6911 - val_binary_accuracy: 0.5942 - val_auc: 0.6276
# Epoch 271/300
# 1/1 - 0s - loss: 4.3674 - binary_accuracy: 0.6163 - auc: 0.6354 - val_loss: 3.7256 - val_binary_accuracy: 0.5929 - val_auc: 0.6264
# Epoch 272/300
# 1/1 - 0s - loss: 4.5425 - binary_accuracy: 0.5968 - auc: 0.6143 - val_loss: 3.7473 - val_binary_accuracy: 0.5922 - val_auc: 0.6254
# Epoch 273/300
# 1/1 - 0s - loss: 4.4616 - binary_accuracy: 0.5990 - auc: 0.6155 - val_loss: 3.7472 - val_binary_accuracy: 0.5919 - val_auc: 0.6251
# Epoch 274/300
# 1/1 - 0s - loss: 4.1618 - binary_accuracy: 0.6229 - auc: 0.6450 - val_loss: 3.7518 - val_binary_accuracy: 0.5914 - val_auc: 0.6246
# Epoch 275/300
# 1/1 - 0s - loss: 4.4230 - binary_accuracy: 0.5967 - auc: 0.6154 - val_loss: 3.7409 - val_binary_accuracy: 0.5918 - val_auc: 0.6246
# Epoch 276/300
# 1/1 - 0s - loss: 4.3741 - binary_accuracy: 0.5936 - auc: 0.6124 - val_loss: 3.7333 - val_binary_accuracy: 0.5917 - val_auc: 0.6243
# Epoch 277/300
# 1/1 - 0s - loss: 4.3316 - binary_accuracy: 0.6094 - auc: 0.6304 - val_loss: 3.7313 - val_binary_accuracy: 0.5913 - val_auc: 0.6240
# Epoch 278/300
# 1/1 - 0s - loss: 4.3478 - binary_accuracy: 0.6128 - auc: 0.6291 - val_loss: 3.7488 - val_binary_accuracy: 0.5908 - val_auc: 0.6237
# Epoch 279/300
# 1/1 - 0s - loss: 4.8160 - binary_accuracy: 0.5979 - auc: 0.6135 - val_loss: 3.7276 - val_binary_accuracy: 0.5910 - val_auc: 0.6242
# Epoch 280/300
# 1/1 - 0s - loss: 5.8263 - binary_accuracy: 0.5783 - auc: 0.5920 - val_loss: 3.6849 - val_binary_accuracy: 0.5923 - val_auc: 0.6253
# Epoch 281/300
# 1/1 - 0s - loss: 4.3288 - binary_accuracy: 0.6020 - auc: 0.6207 - val_loss: 3.6490 - val_binary_accuracy: 0.5932 - val_auc: 0.6265
# Epoch 282/300
# 1/1 - 0s - loss: 4.4851 - binary_accuracy: 0.5976 - auc: 0.6121 - val_loss: 3.6133 - val_binary_accuracy: 0.5941 - val_auc: 0.6281
# Epoch 283/300
# 1/1 - 0s - loss: 4.2442 - binary_accuracy: 0.6065 - auc: 0.6256 - val_loss: 3.5753 - val_binary_accuracy: 0.5945 - val_auc: 0.6296
# Epoch 284/300
# 1/1 - 0s - loss: 4.6240 - binary_accuracy: 0.6116 - auc: 0.6313 - val_loss: 3.5538 - val_binary_accuracy: 0.5953 - val_auc: 0.6298
# Epoch 285/300
# 1/1 - 0s - loss: 4.2880 - binary_accuracy: 0.6028 - auc: 0.6240 - val_loss: 3.5317 - val_binary_accuracy: 0.5951 - val_auc: 0.6304
# Epoch 286/300
# 1/1 - 0s - loss: 4.5874 - binary_accuracy: 0.6077 - auc: 0.6254 - val_loss: 3.5176 - val_binary_accuracy: 0.5950 - val_auc: 0.6306
# Epoch 287/300
# 1/1 - 0s - loss: 4.0060 - binary_accuracy: 0.5832 - auc: 0.6039 - val_loss: 3.5110 - val_binary_accuracy: 0.5949 - val_auc: 0.6307
# Epoch 288/300
# 1/1 - 0s - loss: 5.3244 - binary_accuracy: 0.5768 - auc: 0.5872 - val_loss: 3.5149 - val_binary_accuracy: 0.5953 - val_auc: 0.6307
# Epoch 289/300
# 1/1 - 0s - loss: 4.4730 - binary_accuracy: 0.5888 - auc: 0.6062 - val_loss: 3.5051 - val_binary_accuracy: 0.5951 - val_auc: 0.6311
# Epoch 290/300
# 1/1 - 0s - loss: 4.3669 - binary_accuracy: 0.6012 - auc: 0.6198 - val_loss: 3.4891 - val_binary_accuracy: 0.5954 - val_auc: 0.6313
# Epoch 291/300
# 1/1 - 0s - loss: 4.2241 - binary_accuracy: 0.6245 - auc: 0.6441 - val_loss: 3.4763 - val_binary_accuracy: 0.5948 - val_auc: 0.6312
# Epoch 292/300
# 1/1 - 0s - loss: 5.1616 - binary_accuracy: 0.6014 - auc: 0.6185 - val_loss: 3.4618 - val_binary_accuracy: 0.5944 - val_auc: 0.6316
# Epoch 293/300
# 1/1 - 0s - loss: 4.3718 - binary_accuracy: 0.5973 - auc: 0.6178 - val_loss: 3.4499 - val_binary_accuracy: 0.5946 - val_auc: 0.6320
# Epoch 294/300
# 1/1 - 0s - loss: 4.2958 - binary_accuracy: 0.6168 - auc: 0.6381 - val_loss: 3.4413 - val_binary_accuracy: 0.5947 - val_auc: 0.6327
# Epoch 295/300
# 1/1 - 0s - loss: 4.3472 - binary_accuracy: 0.6219 - auc: 0.6473 - val_loss: 3.4339 - val_binary_accuracy: 0.5942 - val_auc: 0.6329
# Epoch 296/300
# 1/1 - 0s - loss: 4.2653 - binary_accuracy: 0.6078 - auc: 0.6297 - val_loss: 3.4221 - val_binary_accuracy: 0.5953 - val_auc: 0.6330
# Epoch 297/300
# 1/1 - 0s - loss: 5.1501 - binary_accuracy: 0.6059 - auc: 0.6178 - val_loss: 3.4133 - val_binary_accuracy: 0.5938 - val_auc: 0.6333
# Epoch 298/300
# 1/1 - 0s - loss: 4.3163 - binary_accuracy: 0.6148 - auc: 0.6342 - val_loss: 3.4069 - val_binary_accuracy: 0.5941 - val_auc: 0.6334
# Epoch 299/300
# 1/1 - 0s - loss: 4.3282 - binary_accuracy: 0.5973 - auc: 0.6175 - val_loss: 3.4025 - val_binary_accuracy: 0.5939 - val_auc: 0.6334
# Epoch 300/300
# 1/1 - 0s - loss: 4.5625 - binary_accuracy: 0.6211 - auc: 0.6402 - val_loss: 3.3983 - val_binary_accuracy: 0.5947 - val_auc: 0.6339

# %%
sg.utils.plot_history(history)

# %%
train_metrics = model.evaluate(train_flow)
test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4036 - binary_accuracy: 0.5955 - auc: 0.6359
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3983 - binary_accuracy: 0.5947 - auc: 0.6339
#
# Train Set Metrics of the trained model:
# 	loss: 3.4036
# 	binary_accuracy: 0.5955
# 	auc: 0.6359
#
# Test Set Metrics of the trained model:
# 	loss: 3.3983
# 	binary_accuracy: 0.5947
# 	auc: 0.6339

# %%
test_metrics
# Out:
# [3.398266315460205, 0.5946640968322754, 0.6338756680488586]

# %%
res_pred = model.predict(test_flow)
tmp = pd.DataFrame({"pred": res_pred[0], "label": edge_labels_test})
tmp
# Out:
#                 pred  label
# 0       1.000000e+00      1
# 1       8.022879e-05      1
# 2       1.318255e-03      1
# 3       3.703873e-03      1
# 4       1.000000e+00      1
# ...              ...    ...
# 131481  9.980637e-01      0
# 131482  9.999999e-01      0
# 131483  1.109460e-08      0
# 131484  7.144993e-03      0
# 131485  5.459324e-03      0
#
# [131486 rows x 2 columns]

# %%
accuracy_score(edge_labels_test, res_pred[0]>0.4), roc_auc_score(edge_labels_test, res_pred[0])
import seaborn as sns, numpy as np
sns.distplot(tmp[tmp.label==1].pred)
sns.distplot(tmp[tmp.label==0].pred, color="r")
